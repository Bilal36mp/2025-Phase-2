# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilal36mp/2025-Phase-2/blob/main/notebooks/my_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

df_sales = pd.read_csv('store_sales.csv', encoding='latin-1')
# Out:
#      <input type="file" id="files-120c5842-e2a3-452c-a90c-02d1eba8fbad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-120c5842-e2a3-452c-a90c-02d1eba8fbad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_sales.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812   6/09/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812   6/09/2014   6/14/2014  Standard Class    BH-11710
# 5      24  US-2017-156909   7/16/2017   7/18/2017    Second Class    SF-20065
# 6      25  CA-2015-106320   9/25/2015   9/30/2015  Standard Class    EB-13870
# 7      28  US-2015-150630   9/17/2015   9/21/2015  Standard Class    TB-21520
# 8      30  US-2015-150630   9/17/2015   9/21/2015  Standard Class    TB-21520
# 9      37  CA-2016-117590  12/08/2016  12/10/2016     First Class    GH-14485
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df_sales_client = df_sales["Sales"].mean()
print(df_sales_client)
sd_sales = df_sales["Sales"].std()
print(sd_sales)
df_dis_sales = df_sales["Discount"].mean()
print(df_dis_sales)
sd_dis = df_sales["Discount"].std()
print(sd_dis)
# Out:
# 349.8348869872702
# 503.1791448146307
# 0.1739226779820839
# 0.1815472849149642

# %%
from matplotlib import pyplot as plt

# Variables: Sales, Discounts, Quantity, Profit
# Plots: Barplot, Histograms, Box and Whisker Plots


var_sales = df_sales["Sales"]

fig = plt.figure(figsize=(10,4))

plt.hist(var_sales)
plt.title("Sales")
plt.xlabel(df_sales["Sub-Category"])
plt.ylabel("Amount ($)")

fig.show()
# Out:
#      <input type="file" id="files-97423649-255f-4c6a-9f45-c80b5aeb4997" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97423649-255f-4c6a-9f45-c80b5aeb4997">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
